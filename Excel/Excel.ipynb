# %%
import numpy as np
import pandas as pd

# %%
pd.read_excel("file_example_XLSX_10.xlsx")
# Out:
#    0 First Name  Last Name  Gender        Country  Age        Date    Id
# 0  1      Dulce      Abril  Female  United States   32  15/10/2017  1562
# 1  2       Mara  Hashimoto  Female  Great Britain   25  16/08/2016  1582
# 2  3     Philip       Gent    Male         France   36  21/05/2015  2587
# 3  4   Kathleen     Hanner  Female  United States   25  15/10/2017  3549
# 4  5    Nereida    Magwood  Female  United States   58  16/08/2016  2468
# 5  6     Gaston      Brumm    Male  United States   24  21/05/2015  2554
# 6  7       Etta       Hurn  Female  Great Britain   56  15/10/2017  3598
# 7  8    Earlean     Melgar  Female  United States   27  16/08/2016  2456
# 8  9   Vincenza    Weiland  Female  United States   40  21/05/2015  6548

# %%
wypadki = pd.read_excel("WypadkiwgwojewodztwIX2016.xls", header= 2, usecols=[1,2,3,4], skipfooter=1, index_col=0) 
wypadki
# Out:
#                                                     ciężki   inny  śmiertelny
# Przedszkole                                             10   2228           0
# Szkoła podstawowa                                       62  30737           0
# Gimnazjum                                               53  21513           4
# Zasadnicza szkoła zawodowa                               0   1077           1
# Liceum ogólnokształcące                                 13   4666           0
# Technikum                                                6   4031           0
# Szkoła policealna (ponadgimnazjalna)                     0     51           0
# Szkoła specjalna przysposabiająca do pracy dla ...       1     55           0
# Sześcioletnia ogólnokształcąca szkoła muzyczna ...       0     99           0
# Sześcioletnia szkoła muzyczna I stopnia                  0      1           0
# Czteroletnia szkoła muzyczna I stopnia                   0      1           0
# ...

# %%
wypadki2 = pd.read_excel("WypadkiwgwojewodztwIX2016.xls", sheet_name = "wg województw", header= 2, usecols=[1,3,4,5,6], skipfooter=1, index_col=[1,0]) 
wypadki2.sort_index(level=0)
# Out:
#                                                                        ciężki  \
# Bednarska Szkoła Realna                      WOJ. MAZOWIECKIE               0
# Bursa                                        WOJ. DOLNOŚLĄSKIE              0
#                                              WOJ. KUJAWSKO-POMORSKIE        0
#                                              WOJ. LUBELSKIE                 0
#                                              WOJ. MAŁOPOLSKIE               0
#                                              WOJ. PODLASKIE                 0
#                                              WOJ. POMORSKIE                 0
#                                              WOJ. WARMIŃSKO-MAZURSKIE       0
#                                              WOJ. WIELKOPOLSKIE             0
#                                              WOJ. ZACHODNIOPOMORSKIE        0
#                                              WOJ. ŁÓDZKIE                   0
# ...
